# %% [markdown]
# # import library and dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 252          253         0       1        Stead, Mr. William Thomas    male
# 554          555         1       3               Ohman, Miss. Velin  female
# 218          219         1       1            Bazzani, Miss. Albina  female
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 277          278         0       2      Parkes, Mr. Francis "Frank"    male
#
#        Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 252  62.00      0      0  113514  26.5500   C87        S
# 554  22.00      0      0  347085   7.7750   NaN        S
# 218  32.00      0      0   11813  76.2917   D15        C
# 803   0.42      0      1    2625   8.5167   NaN        C
# 277    NaN      0      0  239853   0.0000   NaN        S

# %% [markdown]
# # 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 647          648         1       1  Simonius-Blumer, Col. Oberst Alfons
# 4              5         0       3             Allen, Mr. William Henry
# 382          383         0       3                   Tikkanen, Mr. Juho
# 19            20         1       3              Masselmani, Mrs. Fatima
# 827          828         1       2                Mallet, Master. Andre
#
#         Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# 647    male  56.0      0      0              13213  35.5000   A26        C
# 4      male  35.0      0      0             373450   8.0500   NaN        S
# 382    male  32.0      0      0  STON/O 2. 3101293   7.9250   NaN        S
# 19   female   NaN      0      0               2649   7.2250   NaN        C
# 827    male   1.0      0      2    S.C./PARIS 2079  37.0042   NaN        C

# %% [markdown]
# # 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 7. How is the correlation between cols?

# %% [markdown]
# ## Select only numarical columns

# %%
numeric_cols = df.select_dtypes(include=['number'])

# %%
correlation_matrix = numeric_cols.corr()

# %%
correlation_matrix
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ## Replace dummy(object) columns with numarical values

# %%
df_encoded = pd.get_dummies(df)
correlation_matrix_all = df_encoded.corr()

# %%
correlation_matrix_all
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# ...                  ...       ...       ...       ...       ...       ...
# Cabin_G6       -0.060049  0.016040  0.055561 -0.077296 -0.001402  0.072388
# Cabin_T        -0.013814 -0.026456 -0.052496  0.039474 -0.015907 -0.015878
# Embarked_C     -0.001205  0.168240 -0.243292  0.036261 -0.059528 -0.011069
# Embarked_Q     -0.033606  0.003650  0.221009 -0.022405 -0.026354 -0.081228
# Embarked_S      0.022148 -0.155660  0.081720 -0.032523  0.070941  0.063036
#
#                  Fare  Name_Abbing, Mr. Anthony  \
# PassengerId  0.012658                  0.052129
# Survived     0.257307                 -0.026456
# Pclass      -0.549500                  0.027734
# Age          0.096067                  0.031735
# SibSp        0.159651                 -0.015907
# ...               ...                       ...
# Cabin_G6    -0.025180                 -0.002251
# Cabin_T      0.002224                 -0.001124
# Embarked_C   0.269335                 -0.016158
# Embarked_Q  -0.117216                 -0.010310
# Embarked_S  -0.166603                  0.020759
#
#              Name_Abbott, Mr. Rossmore Edward  \
# PassengerId                          0.039227
# Survived                            -0.026456
# Pclass                               0.027734
# Age                                 -0.035342
# SibSp                                0.014507
# ...                                       ...
# Cabin_G6                            -0.002251
# Cabin_T                             -0.001124
# Embarked_C                          -0.016158
# Embarked_Q                          -0.010310
# Embarked_S                           0.020759
#
#              Name_Abbott, Mrs. Stanton (Rosa Hunt)  ...  Cabin_F G73  \
# PassengerId                              -0.021633  ...    -0.009220
# Survived                                  0.042470  ...    -0.037436
# Pclass                                    0.027734  ...     0.039243
# Age                                       0.013676  ...    -0.028110
# SibSp                                     0.014507  ...    -0.022508
# ...                                            ...  ...          ...
# Cabin_G6                                 -0.002251  ...    -0.003185
# Cabin_T                                  -0.001124  ...    -0.001590
# Embarked_C                               -0.016158  ...    -0.022864
# Embarked_Q                               -0.010310  ...    -0.014588
# Embarked_S                                0.020759  ...     0.029374
#
#              Cabin_F2  Cabin_F33  Cabin_F38  Cabin_F4  Cabin_G6   Cabin_T  \
# PassengerId -0.049263  -0.030733   0.043137 -0.008206 -0.060049 -0.013814
# Survived     0.033803   0.073642  -0.026456  0.060095  0.016040 -0.026456
# Pclass      -0.021469  -0.021469   0.027734 -0.017519  0.055561 -0.052496
# Age         -0.070995  -0.003128        NaN -0.099305 -0.077296  0.039474
# SibSp        0.007576  -0.027582  -0.015907  0.063564 -0.001402 -0.015907
# ...               ...        ...        ...       ...       ...       ...
# Cabin_G6    -0.003903  -0.003903  -0.002251 -0.003185  1.000000 -0.002251
# Cabin_T     -0.001948  -0.001948  -0.001124 -0.001590 -0.002251  1.000000
# Embarked_C  -0.028018  -0.028018  -0.016158 -0.022864 -0.032371 -0.016158
# Embarked_Q  -0.017877  -0.017877   0.108986 -0.014588 -0.020654 -0.010310
# Embarked_S   0.035996   0.035996  -0.054125  0.029374  0.041589  0.020759
#
#              Embarked_C  Embarked_Q  Embarked_S
# PassengerId   -0.001205   -0.033606    0.022148
# Survived       0.168240    0.003650   -0.155660
# Pclass        -0.243292    0.221009    0.081720
# Age            0.036261   -0.022405   -0.032523
# SibSp         -0.059528   -0.026354    0.070941
# ...                 ...         ...         ...
# Cabin_G6      -0.032371   -0.020654    0.041589
# Cabin_T       -0.016158   -0.010310    0.020759
# Embarked_C     1.000000   -0.148258   -0.778359
# Embarked_Q    -0.148258    1.000000   -0.496624
# Embarked_S    -0.778359   -0.496624    1.000000
#
# [1731 rows x 1731 columns]
