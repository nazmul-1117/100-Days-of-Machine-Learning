# %% [markdown]
# # Import library

# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv('orders.csv')
df.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# # Convert object to datetime

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# # Play with Date

# %%
df['day'] = df['date'].dt.day
df.head(5)
# Out:
#         date  product_id  city_id  orders  day
# 0 2019-12-10        5628       25       3   10
# 1 2018-08-15        3646       14     157   15
# 2 2018-10-23        1859       25       1   23
# 3 2019-08-17        7292       25       1   17
# 4 2019-01-06        4344       25       3    6

# %%
df['month'] = df['date'].dt.month
df.head(5)
# Out:
#         date  product_id  city_id  orders  day  month
# 0 2019-12-10        5628       25       3   10     12
# 1 2018-08-15        3646       14     157   15      8
# 2 2018-10-23        1859       25       1   23     10
# 3 2019-08-17        7292       25       1   17      8
# 4 2019-01-06        4344       25       3    6      1

# %%
df['year'] = df['date'].dt.year
df.head(5)
# Out:
#         date  product_id  city_id  orders  day  month  year
# 0 2019-12-10        5628       25       3   10     12  2019
# 1 2018-08-15        3646       14     157   15      8  2018
# 2 2018-10-23        1859       25       1   23     10  2018
# 3 2019-08-17        7292       25       1   17      8  2019
# 4 2019-01-06        4344       25       3    6      1  2019

# %% [markdown]
# ## play with name

# %%
df['month_name'] = df['date'].dt.month_name()
df.head(5)
# Out:
#         date  product_id  city_id  orders  day  month  year month_name
# 0 2019-12-10        5628       25       3   10     12  2019   December
# 1 2018-08-15        3646       14     157   15      8  2018     August
# 2 2018-10-23        1859       25       1   23     10  2018    October
# 3 2019-08-17        7292       25       1   17      8  2019     August
# 4 2019-01-06        4344       25       3    6      1  2019    January

# %%
df['day_name'] = df['date'].dt.day_name()
df.head(5)
# Out:
#         date  product_id  city_id  orders  day  month  year month_name  \
# 0 2019-12-10        5628       25       3   10     12  2019   December
# 1 2018-08-15        3646       14     157   15      8  2018     August
# 2 2018-10-23        1859       25       1   23     10  2018    October
# 3 2019-08-17        7292       25       1   17      8  2019     August
# 4 2019-01-06        4344       25       3    6      1  2019    January
#
#    day_of_week  day_of_year   day_name
# 0            1          344    Tuesday
# 1            2          227  Wednesday
# 2            1          296    Tuesday
# 3            5          229   Saturday
# 4            6            6     Sunday

# %%
df['day_of_week'] = df['date'].dt.day_of_week
df.head(5)
# Out:
#         date  product_id  city_id  orders  day  month  year month_name  \
# 0 2019-12-10        5628       25       3   10     12  2019   December
# 1 2018-08-15        3646       14     157   15      8  2018     August
# 2 2018-10-23        1859       25       1   23     10  2018    October
# 3 2019-08-17        7292       25       1   17      8  2019     August
# 4 2019-01-06        4344       25       3    6      1  2019    January
#
#    day_of_week
# 0            1
# 1            2
# 2            1
# 3            5
# 4            6

# %%
df['day_of_year'] = df['date'].dt.day_of_year
df.head(5)
# Out:
#         date  product_id  city_id  orders  day  month  year month_name  \
# 0 2019-12-10        5628       25       3   10     12  2019   December
# 1 2018-08-15        3646       14     157   15      8  2018     August
# 2 2018-10-23        1859       25       1   23     10  2018    October
# 3 2019-08-17        7292       25       1   17      8  2019     August
# 4 2019-01-06        4344       25       3    6      1  2019    January
#
#    day_of_week  day_of_year
# 0            1          344
# 1            2          227
# 2            1          296
# 3            5          229
# 4            6            6

# %%
# is weekend?

df['date_is_weekend'] = np.where(df['day_name'].isin(['Sunday', 'Saturday']), 1,0)

df.head(5)
# Out:
#         date  product_id  city_id  orders  day  month  year month_name  \
# 0 2019-12-10        5628       25       3   10     12  2019   December
# 1 2018-08-15        3646       14     157   15      8  2018     August
# 2 2018-10-23        1859       25       1   23     10  2018    October
# 3 2019-08-17        7292       25       1   17      8  2019     August
# 4 2019-01-06        4344       25       3    6      1  2019    January
#
#    day_of_week  day_of_year   day_name  date_is_weekend
# 0            1          344    Tuesday                0
# 1            2          227  Wednesday                0
# 2            1          296    Tuesday                0
# 3            5          229   Saturday                1
# 4            6            6     Sunday                1

# %%
df.drop(columns=['product_id', 'city_id'], inplace=True)

# %%
df.head(5)
# Out:
#         date  orders  day  month  year month_name  day_of_week  day_of_year  \
# 0 2019-12-10       3   10     12  2019   December            1          344
# 1 2018-08-15     157   15      8  2018     August            2          227
# 2 2018-10-23       1   23     10  2018    October            1          296
# 3 2019-08-17       1   17      8  2019     August            5          229
# 4 2019-01-06       3    6      1  2019    January            6            6
#
#     day_name  date_is_weekend
# 0    Tuesday                0
# 1  Wednesday                0
# 2    Tuesday                0
# 3   Saturday                1
# 4     Sunday                1

# %% [markdown]
# # Extract Time elapsed between dates

# %%
today = datetime.datetime.today()

# %%
today
# Out:
# datetime.datetime(2025, 2, 19, 15, 26, 54, 21476)

# %%
today - df['date']
# Out:
# 0     1898 days 15:26:54.021476
# 1     2380 days 15:26:54.021476
# 2     2311 days 15:26:54.021476
# 3     2013 days 15:26:54.021476
# 4     2236 days 15:26:54.021476
#                  ...
# 995   2326 days 15:26:54.021476
# 996   2267 days 15:26:54.021476
# 997   2115 days 15:26:54.021476
# 998   2180 days 15:26:54.021476
# 999   1954 days 15:26:54.021476
# Name: date, Length: 1000, dtype: timedelta64[ns]
