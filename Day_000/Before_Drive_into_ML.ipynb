# %% [markdown]
# # Some Fellings
#
# ```
# I’m very passionate about Machine Learning from 2020.
# I think I loved the Generative AI field. Here my goal is,
# I will have a personal assistant who will do my every work and help me in every situation.
# Let’s see what will happen. I’m very excited to drive into this awesome journey.
# Everything will be fair and lovely insha’Allah.
#
# Data: 8 February 2025
# Day: Saturday
# Time: 8:58 PM
#
# ```

# %% [markdown]
# # Install Python
#
#
# ```
#  - Download from Website
#  - Makes sure mark on "Add python.exe to path"
#  - Install Python
# ```

# %% [markdown]
# # Create & Active Virtual Environment
#
#
# ```
# - pip install virtualenv
# - virtualenv venv
# - dir
# - venv\script\activate
# ```

# %% [markdown]
# # Notebook install
#
#
# ```
# - pip install jupyter
# ```

# %% [markdown]
# # Virtual env in jupyter
#
#
# ```
# - python -m ipykernel install --user --name = venv
# - jupyter kernelspace list
# ```

# %% [markdown]
# # Show installed Library
#
#
# ```
# - pip freeze
# ```
